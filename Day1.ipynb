# %%
a=10
type(a)
# Out:
# int

# %%
a=10
a='Ganesh'
a=30.5
type(a)
# Out:
# float

# %%
name='Ganesh'
type(name)
# Out:
# str

# %%
_Rupees=10
_Rupees
# Out:
# 10

# %%
Ganesh='SRM UNIVERSITY'
Ganesh
# Out:
# 'SRM UNIVERSITY'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
A=10
A
# Out:
# 10

# %%
A=10
B=50
print(A+B)
# Out:
# 60

# %%
a,b,c=15,25,10
a+b+c
# Out:
# 50

# %%
dol_lar=70
dol_lar
# Out:
# 70
