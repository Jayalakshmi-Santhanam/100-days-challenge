# %%
a=5
type(a)
id(a)
# Out:
# 140724660704168

# %%
c=-3
type(c)
# Out:
# int

# %%
0b10101
# Out:
# 21

# %%
0o010123
# Out:
# 4179

# %%
0x1237
# Out:
# 4663

# %%
a=567.99
type(a)
# Out:
# float

# %%
4e5
# Out:
# 400000.0

# %%
a=15
bin(a)
# Out:
# '0b1111'

# %%
b=71
bin(b)
# Out:
# '0b1000111'

# %%
a='12456'
type(a)
# Out:
# str

# %%
a=""""hello, I am Ganesh
   from chennai"""
a
# Out:
# '"hello, I am Ganesh\n   from chennai'

# %%
a=True
type(a)
# Out:
# bool

# %%
a=5+3j
a.real
a.imag
# Out:
# 3.0

# %%
a=5
b=10
print(id(a))
print(id(b))
# Out:
# 140724660704168
# 140724660704328

# %%
a=100
b=100
print(id(a))
print(id(b))
# Out:
# 140724660707208
# 140724660707208

# %%
a=2+43234j
a
# Out:
# (2+43234j)

# %%
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 43234.0

# %%
a=1
b=1

# %%
id(a)
# Out:
# 140724660704040

# %%
id(b)
# Out:
# 140724660704040

# %%
a=19
b=0b1010001
print(b)
# Out:
# 81
