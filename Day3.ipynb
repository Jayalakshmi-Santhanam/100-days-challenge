# %%
a=[1,2,10,5,6]
a
# Out:
# [1, 2, 10, 5, 6]

# %%
type(a)
# Out:
# list

# %%
a[0:3]
# Out:
# [1, 2, 10]

# %%
a[0:5]
# Out:
# [1, 2, 10, 5, 6]

# %%
a[:5]
# Out:
# [1, 2, 10, 5, 6]

# %%
a[2:]
# Out:
# [10, 5, 6]

# %%
a[:]
# Out:
# [1, 2, 10, 5, 6]

# %%
a[-4]
# Out:
# 2

# %%
a[::-1]
# Out:
# [6, 5, 10, 2, 1]

# %%
b=(1,2,3,4,5)
b
# Out:
# (1, 2, 3, 4, 5)

# %%
type(b)
# Out:
# tuple

# %%
a=(2,4,6,5)
a[0:3]
# Out:
# (2, 4, 6)

# %%
list1=[1,2,3]
list1[0]='Ganesh'
list1
# Out:
# ['Ganesh', 2, 3]

# %%
a=(1,2,3,5,6)
a[0:4]
# Out:
# (1, 2, 3, 5)

# %%
list1.append(7)
list1
# Out:
# ['Ganesh', 2, 3, 7, 7, 7, 7, 7]

# %%
list1.clear()
list1
# Out:
# []

# %%
list1=[1,3,4,2,7,8,9]
list1.append([6,12,10,18,24])
list1
# Out:
# [1, 3, 4, 2, 7, 8, 9, [6, 12, 10, 18, 24]]

# %%
len(list1)
# Out:
# 8

# %%
list1[7][2]
# Out:
# 10

# %%
list1.count(3)
# Out:
# 1

# %%
a=list1.copy
list1
# Out:
# [1, 3, 4, 2, 7, 8, 9, [6, 12, 10, 18, 24]]

# %%
list1.index(3)
# Out:
# 1

# %%
a=[1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.pop()
# Out:
# 5

# %%
a.pop(1)
# Out:
# 2

# %%
c=[1,2,3,4,5,'jai','jai']
c.remove('jai')
c
# Out:
# [1, 2, 3, 4, 5, 'jai']

# %%
c.reverse()
c
# Out:
# ['jai', 5, 4, 3, 2, 1]

# %%
c.remove('jai')
c
# Out:
# [5, 4, 3, 2, 1]

# %%
c.sort()

# %%
c
# Out:
# [1, 2, 3, 4, 5]

# %%
len(c)
# Out:
# 5

# %%
c.reverse()
c
# Out:
# [5, 4, 3, 2, 1]

# %%
c.sort(reverse=True)
c
# Out:
# [5, 4, 3, 2, 1]

# %%
c.sort(reverse=False)
c
# Out:
# [1, 2, 3, 4, 5]

# %%
d=['a','f','z','c','m']
d
# Out:
# ['a', 'f', 'z', 'c', 'm']

# %%
d.sort(reverse=True)

# %%
d
# Out:
# ['z', 'm', 'f', 'c', 'a']

# %%
d.insert(0,'jai')
d
# Out:
# ['jai', 'z', 'm', 'f', 'c', 'a']

# %%
d.insert(3,7)
d
# Out:
# ['jai', 'z', 'm', 7, 'f', 'c', 'a']

# %%
d.extend((1,2,3,5,6))
d
# Out:
# ['jai', 'z', 'm', 7, 'f', 'c', 'a', 1, 2, 3, 5, 6]

# %%
d.extend('lakshmi')
d
# Out:
# ['jai',
#  'z',
#  'm',
#  7,
#  'f',
#  'c',
#  'a',
#  1,
#  2,
#  3,
#  5,
#  6,
#  'l',
#  'a',
#  'k',
#  's',
#  'h',
#  'm',
#  'i']
